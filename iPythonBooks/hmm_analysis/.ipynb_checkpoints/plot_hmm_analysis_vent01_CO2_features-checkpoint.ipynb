# %%
# %matplotlib inline

# %% [markdown]
# # Gaussian HMM
# --------------------------

# %%
from pymongo import MongoClient
import sys
sys.path.append('../../lib')
import rs_common_framework_v4 as rs
import pandas as pd

from __future__ import print_function

import datetime

import numpy as np
from matplotlib import cm, pyplot as plt
from matplotlib.dates import YearLocator, MonthLocator
import plotly.offline as py
import plotly.graph_objs as go  #important library for the plotly
#import cufflinks as cf
import numpy as np
import math
import collections
import numpy as np
import pylab as pl


py.init_notebook_mode(connected=False) # run at the start of every ipython notebook to use plotly.offline
from plotly import tools #to do subplots

from hmmlearn.hmm import GaussianHMM
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

print(__doc__)
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.16.2
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
connection = MongoClient('localhost') #"192.168.6.132"
collection_metadata = connection["project_db"]["metadata"] 
collection_series = connection["project_db"]["filtered_time_series"]
collection_daily_vector = connection["project_db"]["vector_daily"]
collection_statistics = connection["project_db"]["statistics_daily"]

# %%
time_query = dict()
projection_time = dict()
time_df = rs.get_tag_values(collection_series, time_query, projection_time, series_format='DF_t')
start_time = time_df.index[0]._date_repr
end_time = time_df.index[-1]
time_line = pd.date_range(start_time, end_time, freq='1D')
print(start_time, end_time)
# Out:
# 2012-06-23 2015-06-08 23:00:00

# %%
selected_category = ['A', 'B']
l = []
for timestamp in time_line:
    day_type = ['working_day']
    filter_query = {"breakout_group" : selected_category[0], 
                    'timestamp': timestamp._date_repr,
                    'day_type': { '$in': day_type } }
    dictionaries = collection_daily_vector.find_one(filter_query)
    if not dictionaries is None:
        l.append(dictionaries['F_vector'])

X = np.array(l)
print(X.shape)
X
# Out:
# (633, 40)
# array([[ 13.7 ,  16.28,  20.3 , ...,  20.3 ,  18.1 ,  16.55],
#        [ 11.6 ,  13.67,  21.1 , ...,  21.1 ,  20.33,  18.4 ],
#        [ 16.4 ,  17.1 ,  26.6 , ...,  26.6 ,  25.1 ,  20.65],
#        ...,
#        [ 12.3 ,  15.65,  26.9 , ...,  26.9 ,  25.35,  21.45],
#        [ 14.7 ,  18.1 ,  30.7 , ...,  30.7 ,  28.67,  23.3 ],
#        [ 14.7 ,  15.97,  21.8 , ...,  21.8 ,  19.7 ,  16.45]])

# %%
print("fitting to HMM and decoding ...", end="")
print()
n_componentes = range(2,11)
model_list = []
hidden_states_list = []
score_samples = []
for n in n_componentes:
    # Make an HMM instance and execute fit
    model = GaussianHMM(n_components=n, covariance_type="diag", n_iter=1000).fit(X)
    model_list.append(model)
    
    # Predict the optimal sequence of internal hidden state
    h = model.predict(X)
    hidden_states_list.append(h)
    score_samples.append(model.predict_proba(X))
    
    print("done: " + str(n) + " components")
# Out:
# fitting to HMM and decoding ...
# done: 2 components
# done: 3 components
# done: 4 components
# done: 5 components
# done: 6 components
# done: 7 components
# done: 8 components
# done: 9 components
# done: 10 components

# %%
feature = 'mean'
tag = 'V005_vent01_CO2'
query_tag = {'tagname': tag, 'day_type': { '$in': day_type }}
projection = {feature:True}
df = rs.get_tag_values(collection_statistics,query_tag,projection,series_format='DF_t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 633 entries, 2012-06-25 to 2015-06-08
# Data columns (total 1 columns):
# mean    633 non-null float64
# dtypes: float64(1)
# memory usage: 9.9 KB

# %%
print("Transition matrix")
print(model.transmat_)
print()

dates = list(df.index)
text = list(df.index.weekday_name)
y = np.array(df[feature])
print("Means and vars of each hidden state")

cols_n = 1
rows_n = 9
fig = tools.make_subplots(rows=rows_n, cols=cols_n, subplot_titles=(n_componentes),shared_xaxes=True)
# Out:
# Transition matrix
# [[  4.36879107e-001   1.59810026e-002   0.00000000e+000   3.23349611e-002
#     1.61674801e-002   0.00000000e+000   2.74862754e-001   1.91439733e-001
#     0.00000000e+000   3.23349610e-002]
#  [  0.00000000e+000   5.38475242e-001   1.92312568e-001   5.12810833e-002
#     8.97482376e-002   1.28208401e-002   2.56161785e-002   0.00000000e+000
#     7.69250105e-002   1.28208400e-002]
#  [  0.00000000e+000   1.26492930e-001   5.52645988e-001   9.73311072e-003
#     9.73310123e-003   2.04069101e-001   0.00000000e+000   0.00000000e+000
#     9.73257693e-002   0.00000000e+000]
#  [  1.92306067e-002   1.53841546e-001   3.84612307e-002   3.07689271e-001
#     1.15383496e-001   1.11296550e-283   3.26932612e-001   0.00000000e+000
#     0.00000000e+000   3.84612373e-002]
#  [  2.73550071e-103   4.34802454e-002   2.17382030e-002   1.52138105e-001
#     5.21755690e-001   0.00000000e+000   8.69821324e-002   0.00000000e+000
#     2.17382030e-002   1.52167421e-001]
# ...

# %%
data = []
j_column = 1
i_row = 1
colors = ['rgb(220, 0, 0)', 'rgb(0, 220, 0)', 'rgb(0, 0, 220)', 'rgb(50, 100, 200)', 
          'rgb(200, 50, 20)', 'rgb(20, 50, 20)', 'rgb(0, 220, 20)', 'rgb(50, 10, 20)',
          'rgb(5, 10, 20)', 'rgb(200, 100, 10)']

for n in range(9):
    
    for i in range(model_list[n].n_components):
        #print("{0}th hidden state".format(i))
        #print("mean = ", model.means_[i])
        #print("var = ", np.diag(model.covars_[i]))
        #print(i)

        df_y = pd.DataFrame()
        df_y = df.copy()
        mask = (hidden_states_list[n] != i)

        df_y[mask] = None  
        trace = go.Scatter(
            x= dates,
            y= np.array(df_y[feature]),
            text = text,
            mode = 'lines+markers',
            line = dict(
                color = (colors[i]),
                width = 1
                ),
            name = 'Component' + str(i)
        )
        fig.append_trace(trace, i_row, j_column)

    trace = go.Scatter(
        x = dates,
        y = y,
        name = feature,
        text = text,
        line = dict(
            color = ('rgb(125, 125, 125)'),
            width = 1,
            dash = 'dot')
        )
    fig.append_trace(trace, i_row, j_column)    

    j_column += 1
    if j_column > cols_n:
        j_column = 1
        i_row += 1
    
    
layout = go.Layout(
    title=tag,
    xaxis=dict(
        title='Time'
    ),
    yaxis=dict(
        title='Value'
    ),
    barmode='overlay',
    bargap=0.01
)

# %%
fig['layout'].update(title='Breakout time')
fig['layout'].update(height=700)
py.iplot(fig)
# Out:
# <div id="421b3aaa-6b12-4d13-a89c-815557cb79ce" style="height: 700px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("421b3aaa-6b12-4d13-a89c-815557cb79ce", [{"y": [544.6619235166667, 562.5060426291666, 600.4901931583333, 624.8817326416668, 641.5259390541668, 626.0352536749999, 617.729775625, 602.7638182, 646.6133603833333, 611.5859989958332, 623.7363407875001, 597.2332420333333, 615.7153207291666, 606.2147669375, 627.9843661083333, 511.9536726333333, 559.9698322708333, 587.0738329, 604.5388572125, 619.67392835, 603.3153278708334, 582.5000641416667, 602.4259158625, 593.6227623624999, 596.9251022458333, 604.0000423875, 620.1583669583334, 604.9103954166668, 619.0695991208333, 594.3076164083334, 620.7971368291667, 614.4053628625, 605.9727743624999, 682.8292781956523, 615.4647193666667, 690.4380886541667, 668.8265244541666, 
# ...

# %%
df_cmp = pd.DataFrame()
df_cmp['dates'] = dates
df_cmp['day'] = text
df_cmp['month_idx'] = df.index.month
df_cmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 3 columns):
# dates        633 non-null datetime64[ns]
# day          633 non-null object
# month_idx    633 non-null int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 12.4+ KB

# %%
def angle_convert(angle):
    if angle > 360:
        return angle - 360
    if angle < 0:
        return 360 + angle
    else:
        return angle

class Radar(object):
    
    def __init__(self, fig, titles, labels, id_label =1, rect=None):
        if rect is None:
            rect = [0.05, 0.05, 0.95, 0.95]
        
        self.max_value = 0.5
        self.n = len(titles)
        angles = np.arange(90, 90-360, -360.0/self.n)
        
        angles = [angle_convert(a) for a in angles]
        self.angles = np.array(angles)
        
        self.axes = [fig.add_axes(rect, projection="polar", label="axes%d" % i) 
                         for i in range(self.n)]
        
        #put the title in each axe
        self.ax = self.axes[0]
        self.ax.set_thetagrids(self.angles, labels=titles, fontsize=10)

        for ax in self.axes[1:]:
            ax.patch.set_visible(False)
            ax.grid("off")
            ax.xaxis.set_visible(False)
            ax.yaxis.set_visible(False)

        self.upgrade_max()
        
    def upgrade_max(self):
        for ax, angle, label in zip(self.axes, self.angles, labels):
            n = 5
            values = np.array(range(1,self.max_value, self.max_value/n))
            values = np.round(values,2)
            ax.set_rgrids(values, angle=angle, labels=values)
            ax.spines["polar"].set_visible(False)
            ax.set_ylim(0, self.max_value)
        #ax.set_rgrids(range(1, 8), angle=angle, labels=label)
        #ax.spines["polar"].set_visible(False)
        #ax.set_ylim(0, 8)

    def plot(self, values, *args, **kw):
        
        values = np.r_[values, values[0]]
        
        if self.max_value <  values.max():
            self.max_value = values.max()  
            self.upgrade_max()
        
        angle = np.deg2rad(np.r_[self.angles, self.angles[0]])
        self.ax.plot(angle, values, *args, **kw)

# %%
#fig = pl.figure(figsize=(4, 4))

#titles = list("MBCDEF")
#labels = []

#radar = Radar(fig, titles, labels)
#radar.plot([1, 3, 2, 8, 4, 3],  "o-", lw=2, alpha=0.4, label="first")
#radar.plot([15, 3, 2, 8, 4, 3],  "o-", lw=2, alpha=0.4, label="second")

#radar.ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
#           ncol=7, mode="expand", borderaxespad=1.5)

# %%
month_idx = list(range(1,13))
month_name = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
titles = month_name
# This is not needed
labels = [] 

for n in range(0,9):
    
    print('n_comp: ',model_list[n].n_components)
    fig = pl.figure(figsize=(4, 4))
    radar = Radar(fig, titles, labels)
    
    for i in range(model_list[n].n_components):
        mask = (hidden_states_list[n] == i)
        month = np.array(df_cmp[mask]['month_idx'])
        n_samples = len(month)
        cnt = dict(collections.Counter(month))
        #print(cnt)
        r = [0]*12
        for ix in month_idx:
            if ix in cnt.keys():
                r[ix-1] = round((cnt[ix] / n_samples)*100,2)
        
        print(n_samples, r)
        radar.plot(r,  "-", lw=1, alpha=0.7, label="Cmp" + str(i+1))
        
    radar.ax.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,ncol=3, mode="expand", borderaxespad=1.5)
# Out:
# n_comp:  2
# 332 [0.3, 0, 2.11, 10.24, 12.35, 13.86, 17.77, 16.87, 13.86, 11.75, 0.9, 0]
# 301 [16.61, 15.61, 15.61, 6.31, 3.65, 0, 0, 0, 0, 6.64, 17.28, 18.27]
# n_comp:  3
# 218 [3.21, 2.29, 14.22, 19.27, 16.97, 5.96, 0.92, 1.83, 8.72, 16.51, 7.34, 2.75]
# 212 [20.75, 19.81, 10.85, 3.77, 0.47, 0, 0, 0, 0, 2.83, 18.4, 23.11]
# 203 [0, 0, 0, 1.48, 6.9, 16.26, 28.08, 25.62, 13.3, 8.37, 0, 0]
# n_comp:  4
# 123 [0.81, 0, 4.88, 23.58, 21.14, 9.76, 2.44, 4.07, 14.63, 16.26, 2.44, 0]
# 131 [5.34, 5.34, 22.14, 11.45, 9.16, 0.76, 0, 0, 0.76, 14.5, 20.61, 9.92]
# 201 [0, 0, 0, 1.49, 6.97, 16.42, 27.86, 25.37, 13.43, 8.46, 0, 0]
# 178 [24.16, 22.47, 10.67, 3.37, 0, 0, 0, 0, 0, 1.69, 14.04, 23.6]
# n_comp:  5
# 66 [0, 0, 0, 1.52, 18.18, 10.61, 10.61, 15.15, 15.15, 28.79, 0, 0]
# 132 [5.3, 6.82, 22.73, 11.36, 8.33, 0.76, 0, 0, 0.76, 12.88, 20.45, 10.61]
# 174 [24.71, 21.84, 10.34, 3.45, 0, 0, 0, 0, 0, 1.72, 14.37, 23.56]
# ...

# %%
y = []
for com_sample in score_samples:
    r = 0
    n = len(com_sample)
    for sample in com_sample:
        max_prob = max(sample)
        r += max_prob
    print(r)
    y.append(r/n)

trace1 = go.Scatter(
    x = np.array(n_componentes),
    y = y,
    mode = 'lines+markers',
    name = 'lines+markers'
)
data = [trace1]
fig = dict(data=data)
py.iplot(fig)
# Out:
# 632.550872746
# 632.724193356
# 631.927834812
# 631.713183468
# 631.580099462
# 632.214078057
# 631.050005789
# 632.70658626
# 632.456258945
# <div id="ccd2f82a-ac1e-4e89-937a-bff1ab19fc31" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ccd2f82a-ac1e-4e89-937a-bff1ab19fc31", [{"y": [0.9992904782717562, 0.9995642865026144, 0.9983062161328101, 0.9979671144833238, 0.9977568711886148, 0.9987584171520707, 0.9969194404243004, 0.9995364711854985, 0.9991410093910507], "name": "lines+markers", "mode": "lines+markers", "type": "scatter", "x": [2, 3, 4, 5, 6, 7, 8, 9, 10]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
