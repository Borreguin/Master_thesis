# %%
# Seasonal analysis of the office building - HMM Analysis

# %% [markdown]
# This notebook analyzes the results from the trainned HMM models. The HMM models were trainend with vector R of the office building, each sample to analyse is derived from the S vector which inside of collection: "daily_vector". Because this is an unsupervised classification (since there is no ground truth) we try to find the best groups that fit the data.

# %% [markdown]
# ## Actions:

# %%
from pymongo import MongoClient
from __future__ import print_function
from sklearn.externals import joblib
from sklearn.cluster import KMeans
from sklearn import metrics 

import sys
sys.path.append('../../../lib')
import rs_common_framework_v4 as rs

import pandas as pd
import datetime
import collections
import numpy as np
import math

from sklearn.decomposition import PCA, IncrementalPCA
from matplotlib import cm, pyplot as plt, style as st, gridspec as gd
from matplotlib.dates import YearLocator, MonthLocator
st.use('seaborn-colorblind')

import plotly.offline as py
import plotly.graph_objs as go  #important library for the plotly
#import cufflinks as cf
import pylab as pl
from IPython.display import display

py.init_notebook_mode(connected=False) # run at the start of every ipython notebook to use plotly.offline
from plotly import tools #to do subplots

from hmmlearn.hmm import GaussianHMM
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

print(__doc__)
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.16.2
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
print("\t Connected to Mongo DB")
#TODO: Change name of daily vector collection:

daily_vector = 'A-A_3-A_4_1-A_4_2-A_6_1-A_6_2' # the best one
#daily_vector = 'A-A_3-A_4_1-A_4_2-A_5_1-A_5_2-A_6_1-A_6_2'
#daily_vector = 'A-A_1-A_2-A_3-A_4_1-A_4_2-A_5_1-A_5_2-A_6_1-A_6_2'
#daily_vector = 'A-A_1-A_3-A_4_1-A_4_2-A_5_1-A_5_2-A_6_1-A_6_2-A_6_3'
#daily_vector = 'A-A_1-A_3-A_4_1-A_4_2-A_5_1-A_5_2-A_6_1-A_6_2'
#daily_vector = 'A-A_1-A_3-A_4_1-A_4_2-A_5_1-A_6_1-A_6_2'
#daily_vector = 'A-A_1-A_4_1-A_4_2-A_5_1-A_6_1-A_6_2'
#daily_vector = 'A-A_4_1-A_4_2-A_5_2-A_6_3'
#daily_vector = 'A-A_1-A_2-A_4_1-A_4_2-A_5_1-A_6_1-A_6_2'
#daily_vector = 'A-A_1-A_2-A_4_1-A_4_2-A_5_1-A_6_1-A_6_2'
#daily_vector ='A-A_3-A_4_1-A_4_2-A_6_1-A_6_2-C_1-C_2'

season = ['summer', 'winter', 't_period_1', 't_period_2'] #'summer', 'winter', 't_period_1', 't_period_2'
day_type = ['weekend', 'working_day', 'holiday'] #'weekend', 'working_day', 'holiday'
#day_type = ['working_day', 'weekend']
connection = MongoClient('localhost') #"192.168.6.132"
collection_metadata = connection["project_db"]["metadata"] 
collection_series = connection["project_db"]["filtered_time_series"]
collection_daily_vector = connection["project_db"][daily_vector]
collection_statistics = connection["project_db"]["statistics_daily"]
collection_statistics_general = connection["project_db"]["statistics_general"]

collection_sax = connection["project_db"]["sax_daily"]
collection_sax_comfort = connection["project_db"]["comfort_room_sax"]
# Out:
# 	 Connected to Mongo DB

# %%
selected_category = 'A'
#path_model = '../../../HMM_models/9F_HMM_season_day_zone_A.pkl'
#path_model = '../../../HMM_models/Draft_models/hmm_S_vector_A.pkl'
file_name = 'hmm_R_vector_'+ selected_category +'_' + daily_vector + '_10.pkl'
#file_name = 'hmm_R_vector_A_vector_daily_winter20.pkl'
path_model = '../../../HMM_models/Draft_models/' + file_name
path_final_model = '../../../HMM_models/Draft_models/named_'
priori_analysis_label = ['Type NC',  'Type WC']
print("\tReading the HMM model: \n\t{0}".format(path_model))
model = joblib.load(path_model)
n_comp = model.n_components

use_priori_analysis_label = False
print("\t-- The trained model has {0} hidden states".format(n_comp))
# Out:
# 	Reading the HMM model:
# 	../../../HMM_models/Draft_models/hmm_R_vector_A_A-A_3-A_4_1-A_4_2-A_6_1-A_6_2-C_1-C_2_10.pkl
# 	-- The trained model has 3 hidden states

# %%
vector_name = 'R_vector'
filter_query = {"breakout_group": selected_category,
                'day_type': {'$in': day_type}}
                #'seasonal_label': { '$in': season }}

timeline = rs.get_timeline(collection_daily_vector, filter_query, freq=None)

# This obtain a normalized vector based on the general mean and general std. (Z-score normalization)
# the general mean and std does not apply the filter_query

df_norm = rs.get_samples_norm_vector(collection_daily_vector, timeline, filter_query, vector_name)
n = len(df_norm.index)
X = np.array(df_norm)

# Creating the array of samples X
day_type_list = list()
week_day_list = list()
for timestamp in timeline:
    projection = {vector_name: True, 'timestamp': True, 'day_type':True, 'weekday_name': True}
    filter_query.update({'timestamp': timestamp}) 
    dictionaries = collection_daily_vector.find_one(filter_query, projection)
    if not dictionaries is None:
        day_type_list.append(dictionaries['day_type'])
        week_day_list.append(dictionaries['weekday_name'])

start_time = df_norm.index[0]
end_time = df_norm.index[-1]
print("\tAnalysis from {0} to {1}, {2} samples, shape of the samples: {3}".format(start_time, end_time, n, X.shape))
# Out:
# 	Analysis from 2012-06-23 to 2015-06-08, 1081 samples, shape of the samples: (1081, 12)

# %%
hidden_states = model.predict(X)  # based on R vector 

print("\tInfering the hidden states from the observed samples. A sequence of {0} hidden status was infered".format(len(hidden_states)))

# Select the main variable for the R vector (i.e. CO2 level) for purposes of visualization
df = pd.DataFrame(index = pd.DatetimeIndex(timeline))
df['month_idx'] = df.index.month
df['day_type'] = day_type_list
df['weekday_name'] = week_day_list
df['hidden_state'] = hidden_states
# Out:
# 	Infering the hidden states from the observed samples. A sequence of 1081 hidden status was infered

# %%
# preparing the data for plotting the results:
# Plot the day_type labels
plt.close('all')
data = list()
day_indx = range(0,len(day_type))

pie = []
label_comp = ['S'+ str(i+1) for i in range(n_comp)]
for i in range(n_comp):
    mask = (hidden_states == i)
    type_sample = np.array(df[mask]['day_type'])
    n_samples = len(type_sample)
    count = dict(collections.Counter(type_sample))
    r = [0] * len(day_type)

    for d, ix in zip(day_type,day_indx):
        if d in count.keys():
            r[ix] = round(count[d] / n_samples * 100, 2)

    data.append(r)
    pie.append(n_samples)
  
print("Given the observated sequence, here the percentage of relevance of each hidden state. In other words,"
      + " the observed samples were matched with {0} hidden states, in the following way:".format(n_comp))

# Making a Pie Graph
#plt.pie(data_pie, labels=label_comp, startangle=90)
df_pie = pd.DataFrame(pie,index=label_comp, columns=['samples'])
print("\n", df_pie)
ax2 = df_pie.plot.pie(subplots=True,figsize=(4, 4),autopct='%1.1f%%')
ax2[0].legend(loc='right', bbox_to_anchor=(0., 1.02, 1., .052),mode="expand", ncol=3)
plt.show()
# Out:
# Given the observated sequence, here the percentage of relevance of each hidden state. In other words, the observed samples were matched with 3 hidden states, in the following way:
#
#      samples
# S1       92
# S2      315
# S3      674

# %%
type_sample = np.array(df['day_type'])
count = dict(collections.Counter(type_sample))
st = sum(count.values())
for k in count:
    count[k] = (count[k]/st)*100

print(count)
# Out:
# {'working_day': 66.9750231267345, 'weekend': 28.21461609620722, 'holiday': 4.810360777058279}

# %%
print("Observe how the hidden states match according to the following labels: {0} \n".format(day_type)) 

if use_priori_analysis_label:
    label_comp = priori_analysis_label

# Making a stacked bar Graph
df_bar = pd.DataFrame(data, columns=day_type)
ax1 = df_bar.plot.bar(stacked=True, figsize=(6, 4))
ind = np.arange(len(label_comp))
ax1.legend(loc='right', bbox_to_anchor=(0., 1.02, 1., .2),mode="expand", ncol=3, borderaxespad=0)
ax1.set_xticks(ind)
ax1.set_xticklabels(label_comp)
print(df_bar)
plt.show()



#print(x)
week_name = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday']
month_idx = list(range(1,13))
month_name = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

#count
# Out:
# Observe how the hidden states match according to the following labels: ['weekend', 'working_day', 'holiday']
#
#    weekend  working_day  holiday
# 0    88.04         2.17     9.78
# 1    63.17        29.21     7.62
# 2     3.71        93.47     2.82

# %%
#this is a class for radar plot used in the next section (don't modify)
def angle_convert(angle):
    if angle > 360:
        return angle - 360
    if angle < 0:
        return 360 + angle
    else:
        return angle

class Radar(object):
    
    def __init__(self, fig, titles, labels, id_label =1, rect=None):
        if rect is None:
            rect = [0.05, 0.05, 0.95, 0.95]
        
        self.max_value = 10
        self.n = len(titles)
        angles = np.arange(90, 90-360, -360.0/self.n)
        
        angles = [angle_convert(a) for a in angles]
        self.angles = np.array(angles)
        
        self.axes = [fig.add_axes(rect, projection="polar", label="axes%d" % i) 
                         for i in range(self.n)]
        
        #put the title in each axe
        self.ax = self.axes[0]
        self.ax.set_thetagrids(self.angles, labels=titles, fontsize=10)

        for ax in self.axes[1:]:
            ax.patch.set_visible(False)
            ax.grid("off")
            ax.xaxis.set_visible(False)
            ax.yaxis.set_visible(False)

        self.upgrade_max()
        
    def upgrade_max(self):
        for ax, angle, label in zip(self.axes, self.angles, labels):
            n = 5
            step = int(self.max_value/n)
            print(self.max_value)
            values = np.array(range(1,int(self.max_value), step))
            values = np.round(values,2)
            ax.set_rgrids(values, angle=angle, labels=values)
            ax.spines["polar"].set_visible(False)
            ax.set_ylim(0, self.max_value)
        #ax.set_rgrids(range(1, 8), angle=angle, labels=label)
        #ax.spines["polar"].set_visible(False)
        #ax.set_ylim(0, 8)

    def plot(self, values, *args, **kw):
        
        values = np.r_[values, values[0]]
        
        if self.max_value <  values.max():
            self.max_value = values.max()  
            self.upgrade_max()
        
        angle = np.deg2rad(np.r_[self.angles, self.angles[0]])
        self.ax.plot(angle, values, *args, **kw)

# %%
week_name = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday']
print("Observe how the hidden states match according to the following labels: \n{0} ".format(week_name)) 

titles = week_name
labels = [] # at the moment we don't need grid labels 

fig = pl.figure(figsize=(4, 4))
radar = Radar(fig, titles, labels)
data = []
for i in range(n_comp):
    # we observe how the hidden states match with the week_name labels
    mask = (hidden_states == i)
    day_label = np.array(df[mask]['weekday_name'])

    n_samples = len(day_label)
    cnt = dict(collections.Counter(day_label))
    r = [0]*7
    for d, ix in zip(week_name,range(7)):
        if d in cnt.keys():
            r[ix] = round((cnt[d] / n_samples)*100,2)

    #radar.plot(r,  "-", lw=2, alpha=0.7, label=label_comp[i])
    radar.plot(r,  "-", lw=2, alpha=0.7, label=label_comp[i])

    
radar.ax.legend(bbox_to_anchor=(-0.2, 1.02, 1.5, .102), loc=3,ncol=3, mode="expand", borderaxespad=1.5)
plt.show()
# Out:
# Observe how the hidden states match according to the following labels:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
month_idx = list(range(1,13))
month_name = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
print("Observe how the hidden states match according to the following labels: \n{0} ".format(month_name)) 
titles = month_name
labels = [] # is not needed (for grid labels) 

fig = pl.figure(figsize=(4, 4))
radar = Radar(fig, titles, labels)

for i in range(n_comp):
    mask = (hidden_states == i)
    month = np.array(df[mask]['month_idx'])
    n_samples = len(month)
    cnt = dict(collections.Counter(month))
    #print(cnt)
    r = [0]*12
    for ix in month_idx:
        if ix in cnt.keys():
            r[ix-1] = round((cnt[ix] / n_samples)*100,2)

    #print(n_samples, r)
    #radar.plot(r,  "-", lw=1, alpha=1, label= label_comp[i])
    radar.plot(r,  "-", lw=1, alpha=1, label= label_comp[i])


radar.ax.legend(bbox_to_anchor=(-0.2, 1.02, 1.4, .1), loc=3,ncol=3, mode="expand", borderaxespad=1.5)
plt.show()
# Out:
# Observe how the hidden states match according to the following labels:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
print("Save the final model in: " + path_final_model + file_name )
print("The hidden_state_name: ", label_comp)
final_model = dict()
final_model['model'] = model
final_model['hidden_state_name'] = label_comp


try:
    joblib.dump(final_model, filename=path_final_model + file_name, compress=3, protocol=2)
except:
    joblib.dump(final_model, filename=file_name, compress=3, protocol=2)
    
print("Observe the mean vector and varaince of each hidden states:")
for i in range(n_comp):
    print("{0}th hidden state".format(i+1))
    print("mean: ", np.round(model.means_[i],1))
    s = np.diag(model.covars_[i])
    print("var: ", np.round(s,2))
    print()
# Out:
# Save the final model in: ../../../HMM_models/Draft_models/named_hmm_R_vector_A_A-A_3-A_4_1-A_4_2-A_6_1-A_6_2-C_1-C_2_10.pkl
# The hidden_state_name:  ['S1', 'S2', 'S3']
# Observe the mean vector and varaince of each hidden states:
# 1th hidden state
# mean:  [ 2.4  2.1  2.4  2.4  2.3  2.3  1.1  2.  -0.4  0.2 -1.5 -1.1]
# var:  [ 0.29  0.3   0.22  0.29  0.26  0.26  0.42  0.25  2.05  1.92  0.89  0.27]
#
# 2th hidden state
# mean:  [ 0.8  0.8  0.5  0.8  0.8  0.8  0.1  0.2 -0.7  0.3 -0.5 -0.5]
# var:  [ 0.13  0.37  0.57  0.13  0.12  0.12  0.58  0.86  1.98  1.16  1.41  0.84]
#
# 3th hidden state
# mean:  [-0.7 -0.7 -0.6 -0.7 -0.7 -0.7 -0.2 -0.5  0.4 -0.3  0.5  0.3]
# var:  [ 0.05  0.2   0.11  0.05  0.07  0.07  1.14  0.42  0.23  1.08  0.26  0.82]

# %% [markdown]
# # PCA Analysis:
# Here we observe the shape of the clusters, so we can evaluate how the clusters behaive.

# %%
n_components = 3 #to visualize in a 3D space (x,y,z)

pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)

df_pca = pd.DataFrame(X_pca, columns = ['x_cord','y_cord','z_cord'])
df_pca['hidden_state'] = hidden_states

print(df_pca.head(5))
# Out:
#      x_cord    y_cord    z_cord  hidden_state
# 0  5.941404  0.121624 -0.045957             0
# 1  2.555167 -0.848318  1.443657             1
# 2 -2.303227  0.115308  0.711912             2
# 3 -1.691061 -1.268679  0.403208             2
# 4 -2.766901 -2.091948  0.839796             2

# %%
fig = plt.figure(figsize=(8, 8))
plt.scatter(df_pca['x_cord'], df_pca['y_cord'], label='PCA visualization')
plt.title("PCA visualization " + vector_name )

plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.show()

# %%
colors = ['#4682b4', '#2e8b57' , '#ffa500', 'navy']
axe1 = 'x_cord'
axe2 = 'y_cord'

fig = plt.figure(figsize=(8, 8))
#ax = fig.add_subplot(111, projection='3d')

for color, i, target_name in zip(colors, range(n_comp), label_comp):
    mask = (df_pca['hidden_state'] == i)
    #print(len(list(df.loc[mask,axe1])))
    plt.scatter(df_pca.loc[mask,axe1], df_pca.loc[mask, axe2],
                color=color, lw=1, label=target_name, alpha=0.5)
    
    #plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1],
    #            color=color, lw=1, label=target_name)

plt.title("PCA visualization - {0}, using HMM ({1}, {2})".format(vector_name, axe1, axe2 ))

plt.legend(loc="best", shadow=False, scatterpoints=1)
#plt.axis([-1.5, 4, -1.5, 1.5])


plt.show()

# %%
axe1 = 'x_cord'
axe2 = 'z_cord'

fig = plt.figure(figsize=(8, 8))
#ax = fig.add_subplot(111, projection='3d')

for color, i, target_name in zip(colors, range(n_comp), label_comp):
    mask = (df_pca['hidden_state'] == i)
    plt.scatter(df_pca.loc[mask,axe1], df_pca.loc[mask, axe2],
                 color=color, lw=1, label=target_name, alpha=0.5)
    
    #plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1],
    #            color=color, lw=1, label=target_name)

plt.title("PCA visualization - {0}, using HMM ({1}, {2})".format(vector_name, axe1, axe2 ))

plt.legend(loc="best", shadow=False, scatterpoints=1)
#plt.axis([-1.5, 4, -1.5, 1.5])


plt.show()

# %%
print('The first component correspond to x axe, second component to y axe, thrid to z axe')
filter_query = {'document':'description'}
projection = {selected_category : True}
component_labels = ['First Component', 'Second Component', 'Third Component', 'Fourth Component']


dictionary_structure = collection_daily_vector.find_one(filter_query, projection)
R_category_list = dictionary_structure[selected_category]['R_category_list']
tag_list = dictionary_structure[selected_category]['tag_list']
subcategory_name = dictionary_structure[selected_category]['subcategory_name']
#feature_list = dictionary_structure[selected_category]['feature_list']

R_reference = list()
for category in R_category_list[1:]:
    for tag in tag_list[category]:
        R_reference.append(subcategory_name[category] + "<br>" + 
                           rs.get_alias(collection_metadata,tag))
R_reference = R_reference

R_reference = np.array(R_reference)
print("The sample size is {0}".format(len(R_reference)))

n_features = 9
data = []
for p, label in zip(pca.components_[:3],component_labels[:3]):
    bar_values = abs(p)
    ind = bar_values.argsort()[-n_features:][::-1] 
    labels = R_reference[ind]
    trace = go.Bar(
        x=labels,
        y=bar_values[ind],
        name=label
    )
    
    data.append(trace)
layout = go.Layout(
    barmode = 'group',
    title = 'Principal Component Analysis',
    height= 700, 
    margin=go.Margin(
        t=100,
        b=200
    ),
    xaxis=dict(
        tickangle=90
    )
)
    
    
fig = go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
# ['Blinds Angle NE<br>Blinds angle N Out', 'Blinds Angle NE<br>Blinds angle N In', 'Blinds Angle NE<br>Blinds angle E Out', 'Blinds Angle NE<br>Blinds angle E In', 'Blinds Height N-out, E-in<br>Blinds height N Out', 'Blinds Height N-out, E-in<br>Blinds height E In', 'Blinds Height N-in, E-out<br>Blinds height N In', 'Blinds Height N-in, E-out<br>Blinds height E Out', 'Temp. Vent. NE Out<br>Temp. Vent. NE Out', 'Temp. Vent. NE In<br>Temp. Vent. NE In', 'Outdoor Temperature<br>Outdoor Temperature', 'Sunshine<br>Sunshine']
# The sample size is 12
# ...

# %%
working_day = 0
weekend = 2
special = 1

df_matrix = pd.DataFrame()
types = range(0,n_comp)
for d in day_type:
    for t in types:
        mask = (df['hidden_state']== t) & (df['day_type'] == d)
        df_matrix.loc[d,t] = len(df[mask].index)

print(df_matrix)
# Out:
#                 0      1      2
# weekend      81.0  199.0   25.0
# working_day   2.0   92.0  630.0
# holiday       9.0   24.0   19.0

# %%
idx = df[mask].index
dates_f = [y._date_repr for y in idx]
r = dict()
result = dict()
for f in dates_f:
    r[f] = 4
result['Data'] =  r
#print(dates_f)
len(dates_f)
mask = (df['hidden_state']== special) & (df['day_type'] == 'working_day')
print(df[mask].index)
# Out:
# DatetimeIndex(['2012-07-19', '2012-08-21', '2012-10-29', '2012-10-30',
#                '2012-11-02', '2012-11-07', '2012-11-29', '2012-11-30',
#                '2012-12-03', '2012-12-04', '2012-12-05', '2012-12-06',
#                '2012-12-07', '2012-12-10', '2012-12-11', '2012-12-12',
#                '2012-12-14', '2013-01-10', '2013-01-16', '2013-01-17',
#                '2013-01-18', '2013-01-21', '2013-01-22', '2013-02-04',
#                '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-11',
#                '2013-02-12', '2013-02-15', '2013-02-20', '2013-02-21',
#                '2013-02-22', '2013-02-25', '2013-02-27', '2013-02-28',
#                '2013-03-01', '2013-03-04', '2013-03-05', '2013-03-14',
#                '2013-03-15', '2013-03-26', '2013-03-27', '2013-04-12',
#                '2013-08-09', '2013-08-30', '2013-10-03', '2013-10-04',
#                '2013-11-08', '2013-11-11', '2013-11-22', '2013-11-26',
# ...

# %%
tag = 'V005_vent01_CO2' #'V102_blinds_height_N_i' #'V005_vent01_CO2' #'V012_vent01_temp_in'  #'V006_vent01_temp_out' 
df_x = rs.get_tag_pivoted_values(collection_series, dates_f, tag)
print(df_x.head(2))
# Out:
#                     0           1           2           3           4   \
# 2012-08-15  542.418649  544.272618  543.961400  543.159280  542.795106
# 2012-10-01  540.444080  539.353342  536.813151  535.184222  535.548868
#
#                     5           6           7           8           9   \
# 2012-08-15  561.760299  571.172960  585.587154  629.248696  720.012097
# 2012-10-01  537.931811  540.321512  551.146983  627.753273  742.910577
#
#                ...              14          15          16         17  \
# 2012-08-15     ...      732.925945  740.520909  723.426081  658.28567
# 2012-10-01     ...      803.845013  811.041131  788.106886  733.81585
#
#                     18          19          20          21          22  \
# 2012-08-15  580.650442  545.731991  540.709879  541.310156  539.235967
# 2012-10-01  644.363544  596.884395  590.310145  593.109014  594.405702
#
#                     23
# 2012-08-15  536.972321
# 2012-10-01  593.664880
#
# [2 rows x 24 columns]

# %%
tags = list()
for category in R_category_list:
    tags.append(tag_list[category][-1])

n_tags = len(tags)
fig, axes = plt.subplots(nrows=n_tags, ncols=3, figsize=(18,24))
medianprops = dict(linewidth=4, color='red')
t_day = 'working_day'
print('We observe the profiles for ', t_day)
for tag, i in zip(tags,range(n_tags)):
    for t in types:
        mask = (df['hidden_state']== t) & (df['day_type'] == t_day)
        idx = df[mask].index 
        dates_f = [y._date_repr for y in idx]
        
        if len(dates_f) > 0:
            df_x = rs.get_tag_pivoted_values(collection_series, dates_f, tag)  
            if i in [0, 4, 5]:
                df_x.plot.box(ax=axes[i][t],notch=False,  medianprops=medianprops, showfliers=False)
            else:
                df_x.plot.box(ax=axes[i][t],notch=False,  medianprops=medianprops, showfliers=True)
            query_dict = {'tagname':tag}
            tit = rs.get_alias(collection_metadata, tag) + " [" + rs.get_field_value(collection_metadata, query_dict, 'units') + "]"
            lol, upl = rs.get_lol_upl(collection_statistics_general, tag)
            dv = (upl - lol) * 0.05
            axes[i][t].set_ylim([lol-dv, upl+dv])
            axes[i][0].set_ylabel(tit, fontsize = 13)
            axes[i][t].set_xlabel('Hours')
            axes[0][t].set_title('Days =' + str(len(dates_f)))
            axes[i][t].set_xticklabels(labels = range(24), rotation=-90)

plt.show()
# Out:
# We observe the profiles for  working_day

# %%
fig, axes = plt.subplots(nrows=n_tags, ncols=3, figsize=(18,24))
medianprops = dict(linewidth=4, color='red')
t_day = 'weekend'

print('We observe the profiles for ', t_day)
for tag, i in zip(tags,range(n_tags)):
    for t in types:
        mask = (df['hidden_state']== t) & (df['day_type'] == t_day)
        idx = df[mask].index 
        dates_f = [y._date_repr for y in idx]
        df_x = rs.get_tag_pivoted_values(collection_series, dates_f, tag)  
        if i in [0, 4, 5]:
            df_x.plot.box(ax=axes[i][t],notch=False,  medianprops=medianprops, showfliers=False)
        else:
            df_x.plot.box(ax=axes[i][t],notch=False,  medianprops=medianprops, showfliers=True)
        query_dict = {'tagname':tag}
        tit = rs.get_alias(collection_metadata, tag) + " [" + rs.get_field_value(collection_metadata, query_dict, 'units') + "]"
        lol, upl = rs.get_lol_upl(collection_statistics_general, tag)
        dv = (upl - lol) * 0.05
        axes[i][t].set_ylim([lol-dv, upl+dv])
        axes[i][0].set_ylabel(tit, fontsize = 13)
        axes[i][t].set_xlabel('Hours')
        axes[0][t].set_title('Days =' + str(len(dates_f)))
        axes[i][t].set_xticklabels(labels = range(24), rotation=-90)
    
plt.show()
# Out:
# We observe the profiles for  weekend

# %%
tag = 'V102_blinds_height_N_i'
df_sax = rs.get_tag_values(collection_sax, time_query, tag, series_format='DF_t')
count = dict(collections.Counter(df_sax[tag]))

pie = []


n_samples = sum(count.values())
v_ = sorted(count.values())
label_pie = sorted(count, key=count.get)
print(label_pie)
r = [0] * len(label_pie)

perc = dict()
for d, ix in zip(label_pie, range(0,len(label_pie))):
    #r[ix] = round(count[d] / n_samples * 100, 2)
    r[ix] = count[d]
    pie.append(r[ix])
    perc[d] = r[ix]
    
# Making a Pie Graph
#plt.pie(data_pie, labels=label_comp, startangle=90)
df_pie = pd.DataFrame(pie,index=label_pie, columns=['samples'])
#print("\n", df_pie)
ax2 = df_pie.plot.bar(subplots=True,figsize=(12, 4))
ax2[0].legend(loc='center', bbox_to_anchor=(0., 1.02, 1., .052),mode="expand", ncol=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-95ba631e48c1> in <module>()
#       1 tag = 'V102_blinds_height_N_i'
# ----> 2 df_sax = rs.get_tag_values(collection_sax, time_query, tag, series_format='DF_t')
#       3 count = dict(collections.Counter(df_sax[tag]))
#       4
#       5 pie = []
#
# NameError: name 'time_query' is not defined

# %%
outlier = [x for x in r if x < 1]
outlier_list = [k for k,v in perc.items() if v < 3] 
S = len(outlier_list)
T = len(label_pie)
R = sum([perc[x] for x in outlier_list])
print(T,S, R)
print("r:", (T-S)/T )
#perc

# %%
dates_f = list()
for out in outlier_list:
    mask = (df_sax[tag] == out)
    dates_f += [x._date_repr for x in df_sax[mask].index]

r = dict()
result = dict()
for f in dates_f:
    r[f] = 5
result['Data'] =  r
#print(result)

# %%
day_type = ['working_day', 'weekend', 'holiday']
season = ['summer', 'winter', 't_period_1', 't_period_2']
filter_query = { 'day_type': { '$in': day_type },
                'seasonal_label': { '$in': season }}
df_sax = rs.get_tag_values(collection_sax,filter_query, tag, series_format='DF_t')
print(df_sax.tail(2))

# %%
sax_word = 'adb'
dates_f = list(df_sax[df_sax[tag]== sax_word].index)
dates_f = [x._date_repr for x in dates_f]
df_x = rs.get_tag_pivoted_values(collection_series, dates_f, tag)
sax_word = 'ddd'
dates_f = list(df_sax[df_sax[tag]== sax_word].index)
dates_f = [x._date_repr for x in dates_f]
df_y = rs.get_tag_pivoted_values(collection_series, dates_f, tag)

# %%
r = dict()
result = dict()
for f in dates_f:
    r[f] = 4
result['Data'] =  r
print(result)

# %%
X = df_x.dropna().values
best_r = 0
best_k = 2
#for k in range(2,10):
#    k_means = KMeans(n_clusters=k).fit(X)
#    r = metrics.silhouette_score(X,k_means.labels_)
#    if r > best_r:
#        best_r = r
#        best_k = k

k_means = KMeans(n_clusters=best_k).fit(X)
centers_x = k_means.cluster_centers_

Y = df_y.dropna().values
best_r = 0
best_k = 2
#for k in range(2,10):
#    k_means = KMeans(n_clusters=k).fit(Y)
#    r = metrics.silhouette_score(X,k_means.labels_)
#    if r > best_r:
#        best_r = r
#        best_k = k

k_means = KMeans(n_clusters=best_k).fit(Y)
centers_y = k_means.cluster_centers_

# %%
x_ = list(range(0,24))

trace0 = go.Scatter(
    x=x_,
    y=centers_x[0],
    fill= None,
    mode='lines',
    name = 'Normal level',
    line=dict(
        color='blue',
    )
    )
trace1 = go.Scatter(
    x=x_,
    y=centers_x[1],
    fill='tonexty',
    mode='lines',
    name = 'Normal level',
    line=dict(
        color='blue',
    )
)

trace2 = go.Scatter(
    x=x_,
    y=centers_y[0],
    fill= None,
    mode='lines',
    name='High level profiles',
    line=dict(
        color='red',
    )
)
trace3 = go.Scatter(
    x=x_,
    y=centers_y[1],
    fill='tonexty',
    mode='lines',
    name='High level profiles',
    line=dict(
        color='red',
    )
)

layout = go.Layout(
    title='Diversity of profiles [Profile -' + sax_word + ']',
    xaxis=dict(
        title='Hours',
        dtick= 1,
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='CO2 level ppm',
        #range=[400,850],
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
) 


data = [trace0, trace1, trace2, trace3]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)



for center in centers_x:
    plt.plot(center)

for center in centers_y:
    plt.plot(center)

    
plt.show()
